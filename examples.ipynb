# %%
from lightcurve_pipeline import create_light_curve
import lightkurve as lk
# Out:
# /Users/alisonduck/anaconda3/envs/myenv/lib/python3.9/site-packages/lightkurve/config/__init__.py:119: UserWarning: The default Lightkurve cache directory, used by download(), etc., has been moved to /Users/alisonduck/.lightkurve/cache. Please move all the files in the legacy directory /Users/alisonduck/.lightkurve-cache to the new location and remove the legacy directory. Refer to https://docs.lightkurve.org/reference/config.html#default-cache-directory-migration for more information.
#   warnings.warn(

# %% [markdown]
# ## Workspace

# %%
lk.search_lightcurve('TIC 4711', mission='TESS')
# Out:
# WARNING: AstropyDeprecationWarning: The update_default_config function is deprecated and may be removed in a future version. [astroquery._astropy_init]
# SearchResult containing 2 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 11 2019    QLP    1800        4711      0.0
#   1 TESS Sector 38 2021    QLP     600        4711      0.0

# %%
create_light_curve('TIC 4711', 'QLP', 11, auto = True, exposure=1800, targetname = 'TOI-3129', 
                   save = False, plot = True, planet='b', published = False, qualityFlag = True)
# Out:
# Sector: 11. Exposure time: 1800 seconds.
# period:  2.3348152 duration:  1.861 h tc:  2459358.079233
# per-point error value 0.0010830423611
# Transith depth: 0.005310, RMS: 0.0011, Depth/RMS: 4.849
